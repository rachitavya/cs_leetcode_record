# %%
import pandas as pd

# %%
data=pd.read_csv("Contact Information (Responses) - Form Responses 1.csv")

# %%
data
# Out:
#               Timestamp                          name  \
# 0   10/27/2023 10:40:04                 Sarthak Singh
# 1   10/26/2023 20:02:05                 Sarthak Tyagi
# 2    10/27/2023 0:28:13            Shreya Bhadauriya
# 3   10/25/2023 22:06:15      AAYUSH KUMAR SHRIVASTAVA
# 4   10/25/2023 13:31:26               Abhas Chaudhari
# ..                  ...                           ...
# 92  10/26/2023 15:06:23            Kushagra Varshney
# 93  10/25/2023 12:57:09             Utkarsh Srivastav
# 94  10/26/2023 14:40:04          Praveen kumar yadav
# 95  10/25/2023 11:28:12  Amay Jaiswal - 2100290120027
# 96  10/25/2023 11:30:07                 Ashwin Yadav
#
#                       rollNo section  \
# 0               200290120148       C
# 1              1900290120102       B
# 2              2100290110161       A
# 3              2100290120003       A
# 4              2100290120004       A
# ..                       ...     ...
# 92             2200290129012       C
# ...

# %%
data=data.drop(columns=['Timestamp'],axis=1)

# %%
student_data_list = data.to_dict(orient='records')

# %%
student_data_list
# Out:
# [{'name': 'Sarthak Singh',
#   'rollNo': '200290120148',
#   'section': 'C',
#   'leetcodeURL': 'https://leetcode.com/banarasi_guy/'},
#  {'name': 'Sarthak Tyagi',
#   'rollNo': '1900290120102',
#   'section': 'B',
#   'leetcodeURL': 'https://leetcode.com/sarthak-tyagi/'},
#  {'name': 'Shreya Bhadauriya ',
#   'rollNo': '2100290110161',
#   'section': 'A',
#   'leetcodeURL': 'shreya9411'},
#  {'name': 'AAYUSH KUMAR SHRIVASTAVA',
#   'rollNo': '2100290120003',
#   'section': 'A',
#   'leetcodeURL': 'https://leetcode.com/AAYUSH_SHRIVASTAVA/'},
#  {'name': 'Abhas Chaudhari',
#   'rollNo': '2100290120004',
#   'section': 'A',
#   'leetcodeURL': 'https://leetcode.com/abhas25/'},
#  {'name': 'Abhishek Gupta ',
#   'rollNo': '2100290120006',
#   'section': 'A',
#   'leetcodeURL': 'https://leetcode.com/Abhishek_rockstar/'},
#  {'name': 'Abhishek Verma',
#   'rollNo': '2100290120009',
#   'section': 'A',
#   'leetcodeURL': 'https://leetcode.com/vermaabhimanyu593/'},
# ...

# %%
student_data_list[0]['name']
# Out:
# 'Sarthak Singh'
